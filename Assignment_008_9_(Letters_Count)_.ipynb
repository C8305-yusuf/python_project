# %% [markdown]
# <a href="https://colab.research.google.com/github/C8305-yusuf/python_project/blob/main/Assignment_008_9_(Letters_Count)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dict ={}
text_analysis = input("please enter a text : ")
for x in text_analysis :
  keys = dict.keys()
  if x in keys :
    dict[x] += 1
  else :
    dict[x] = 1
print(dict)
